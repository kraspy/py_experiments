# %% [markdown]
# ```python
# my_project/
# │
# ├── alembic/                 # Каталог для миграций Alembic
# │   ├── versions/            # Каталог с файлами миграций
# │   └── env.py               # Конфигурационный файл Alembic
# │
# ├── app/                     # Основной каталог приложения
# │   ├── api/                 # Каталог для эндпоинтов API
# │   │   ├── deps.py          # Зависимости для использования в FastAPI
# │   │   └── api_v1/          # Версионирование API
# │   │       ├── endpoints/   # Различные эндпоинты для API
# │   │       └── routers.py   # Маршрутизация для API v1
# │   │
# │   ├── core/                # Конфигурации и настройки ядра
# │   │   ├── config.py        # Конфигурация приложения
# │   │   └── security.py      # Настройки безопасности (например, для JWT)
# │   │
# │   ├── crud/                # CRUD операции (создание, чтение, обновление, удаление)
# │   │   └── crud_user.py     # Пример CRUD для пользователя
# │   │
# │   ├── db/                  # Работа с базой данных
# │   │   ├── base.py          # Базовый класс модели
# │   │   ├── base_class.py    # Вспомогательный класс для базы
# │   │   ├── init_db.py       # Инициализация базы данных
# │   │   └── session.py       # Сессия SQLAlchemy
# │   │
# │   ├── models/              # Модели SQLAlchemy
# │   │   └── user.py          # Пример модели пользователя
# │   │
# │   ├── schemas/             # Схемы Pydantic для валидации и сериализации
# │   │   └── user.py          # Схема пользователя
# │   │
# │   ├── templates/           # Каталог для HTML шаблонов Jinja2
# │   │   └── home.html        # Пример HTML-шаблона
# │   │
# │   ├── web/                 # Каталог для веб-страниц и роутов
# │   │   └── routes.py        # Роуты для веб-страниц
# │   │
# │   └── main.py              # Точка входа в приложение FastAPI
# │
# ├── tests/                   # Каталог для тестов
# │   ├── api/                 # Тесты для API
# │   └── crud/                # Тесты для CRUD операций
# │
# ├── .env                     # Файл с переменными окружения
# ├── alembic.ini              # Конфигурационный файл для Alembic
# └── requirements.txt         # Зависимости проекта
# ```
