# %% [markdown]
# ## Виджеты
# ### [Text elements](https://docs.streamlit.io/develop/api-reference/text)
# #### HEADINGS & BODY
# - `st.title` [doc](https://docs.streamlit.io/develop/api-reference/text/st.title)
# - `st.header` [doc](https://docs.streamlit.io/develop/api-reference/text/st.header)
# - `st.subheader` [doc](https://docs.streamlit.io/develop/api-reference/text/st.subheader)
# - `st.markdown` [doc](https://docs.streamlit.io/develop/api-reference/text/st.markdown)
# #### FORMATTED TEXT
# - `st.caption` [doc](https://docs.streamlit.io/develop/api-reference/text/st.caption)
# - `st.code` [doc](https://docs.streamlit.io/develop/api-reference/text/st.code)
# - `st.divider` [doc](https://docs.streamlit.io/develop/api-reference/text/st.divider)
# - `st.echo` [doc](https://docs.streamlit.io/develop/api-reference/text/st.echo)
# - `st.latex` [doc](https://docs.streamlit.io/develop/api-reference/text/st.latex)
# - `st.text` [doc](https://docs.streamlit.io/develop/api-reference/text/st.text)
# #### UTILITIES
# - `st.html_link_` [doc](https://docs.streamlit.io/develop/api-reference/utilities/st.html)
# ### [Data elements](https://docs.streamlit.io/develop/api-reference/data)
# - `st.dataframe` [doc](https://docs.streamlit.io/develop/api-reference/data/st.dataframe)
# - `st.data_editor` [doc](https://docs.streamlit.io/develop/api-reference/data/st.data_editor)
# - `st.column_config` [doc](https://docs.streamlit.io/develop/api-reference/data/st.column_config)
# - `st.table` [doc](https://docs.streamlit.io/develop/api-reference/data/st.table)
# - `st.metric` [doc](https://docs.streamlit.io/develop/api-reference/data/st.metric)
# - `st.json` [doc](https://docs.streamlit.io/develop/api-reference/data/st.json)
# ### [Chart elements](https://docs.streamlit.io/develop/api-reference/charts)
# #### SIMPLE
# - `st.area_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.area_chart)
# - `st.bar_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.bar_chart)
# - `st.line_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.line_chart)
# - `st.map` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.map)
# - `st.scatter_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.scatter_chart)
# #### ADVANCED
# - `st.altair_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.altair_chart)
# - `st.bokeh_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.bokeh_chart)
# - `st.graphviz_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.graphviz_chart)
# - `st.plotly_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.plotly_chart)
# - `st.pydeck_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.pydeck_chart)
# - `st.pyplot` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.pyplot)
# - `st.vega_lite_chart` [doc](https://docs.streamlit.io/develop/api-reference/charts/st.vega_lite_chart)
# ### [Input widgets](https://docs.streamlit.io/develop/api-reference/widgets)
# #### BUTTONS
# - `st.button` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.button)
# - `st.download_button` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.download_button)
# - `st.form_submit_button_link_` [doc](https://docs.streamlit.io/develop/api-reference/execution-flow/st.form_submit_button)
# - `st.link_button` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.link_button)
# - `st.page_link` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.page_link)
# #### SELECTIONS
# - `st.checkbox` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.checkbox)
# - `st.color_picker` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.color_picker)
# - `st.feedback` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.feedback)
# - `st.multiselect` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.multiselect)
# - `st.pills` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.pills)
# - `st.radio` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.radio)
# - `st.segmented_control` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.segmented_control)
# - `st.selectbox` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.selectbox)
# - `st.select_slider` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.select_slider)
# - `st.toggle` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.toggle)
# #### NUMERIC
# - `st.number_input` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.number_input)
# - `st.slider` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.slider)
# #### DATE & TIME
# - `st.date_input` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.date_input)
# - `st.time_input` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.time_input)
# #### TEXT
# - `st.chat_input_link_` [doc](https://docs.streamlit.io/develop/api-reference/chat/st.chat_input)
# - `st.text_area` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.text_area)
# - `st.text_input` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.text_input)
# #### MEDIA & FILES
# - `st.audio_input` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.audio_input)
# - `st.camera_input` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.camera_input)
# - `st.data_editor_link_` [doc](https://docs.streamlit.io/develop/api-reference/data/st.data_editor)
# - `st.file_uploader` [doc](https://docs.streamlit.io/develop/api-reference/widgets/st.file_uploader)
# ### [Media elements](https://docs.streamlit.io/develop/api-reference/media)
# - `st.audio` [doc](https://docs.streamlit.io/develop/api-reference/media/st.audio)
# - `st.image` [doc](https://docs.streamlit.io/develop/api-reference/media/st.image)
# - `st.logo` [doc](https://docs.streamlit.io/develop/api-reference/media/st.logo)
# - `st.video` [doc](https://docs.streamlit.io/develop/api-reference/media/st.video)
# ### [Layouts & containers](https://docs.streamlit.io/develop/api-reference/layout)
# - `st.columns` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.columns)
# - `st.container` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.container)
# - `st.dialog_link_` [doc](https://docs.streamlit.io/develop/api-reference/execution-flow/st.dialog)
# - `st.empty` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.empty)
# - `st.expander` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.expander)
# - `st.form_link_` [doc](https://docs.streamlit.io/develop/api-reference/execution-flow/st.form)
# - `st.popover` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.popover)
# - `st.sidebar` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.sidebar)
# - `st.tabs` [doc](https://docs.streamlit.io/develop/api-reference/layout/st.tabs)
# ### [Chat elements](https://docs.streamlit.io/develop/api-reference/chat)
# `{python icon} st.chat_input`  [st.chat_input](https://docs.streamlit.io/develop/api-reference/chat/st.chat_input)
# - `st.chat_message` [doc](https://docs.streamlit.io/develop/api-reference/chat/st.chat_message)
# - `st.status_link_` [doc](https://docs.streamlit.io/develop/api-reference/status/st.status)
# - `st.write_stream_link_` [doc](https://docs.streamlit.io/develop/api-reference/write-magic/st.write_stream)
# ### [Status elements](https://docs.streamlit.io/develop/api-reference/status)
# #### CALLOUTS
# - `st.success` [doc](https://docs.streamlit.io/develop/api-reference/status/st.success)
# - `st.info` [doc](https://docs.streamlit.io/develop/api-reference/status/st.info)
# - `st.warning` [doc](https://docs.streamlit.io/develop/api-reference/status/st.warning)
# - `st.error` [doc](https://docs.streamlit.io/develop/api-reference/status/st.error)
# - `st.exception` [doc](https://docs.streamlit.io/develop/api-reference/status/st.exception)
# #### OTHER
# - `st.progress` [doc](https://docs.streamlit.io/develop/api-reference/status/st.progress)
# - `st.spinner` [doc](https://docs.streamlit.io/develop/api-reference/status/st.spinner)
# - `st.status` [doc](https://docs.streamlit.io/develop/api-reference/status/st.status)
# - `st.toast` [doc](https://docs.streamlit.io/develop/api-reference/status/st.toast)
# - `st.balloons` [doc](https://docs.streamlit.io/develop/api-reference/status/st.balloons)
# - `st.snow` [doc](https://docs.streamlit.io/develop/api-reference/status/st.snow)
