# %% [markdown]
# Переменные и функции взаимодействующие с интерпретатором Python.
#
# [Документация](https://docs.python.org/3/library/sys.html#module-sys)

# %%
import sys

# %% [markdown]
# ## Методы

# %% [markdown]
# ### sys.argv
# Список аргументов командной строки, переданных скрипту Python.\
# Первый элемент списка (sys.argv[0]) - это имя самого скрипта.

# %%
for i, arg in enumerate(sys.argv):
    print(f'Argument {i}: {arg}')
# Out:
# Argument 0: /home/evgeniy/code/py_experiments/.venv/lib/python3.12/site-packages/ipykernel_launcher.py
# Argument 1: --f=/run/user/1000/jupyter/runtime/kernel-v3a1f33c5fed789b1c7577490358320949c3b482ca.json

# %% [markdown]
# ### sys.stdin
# Стандартный поток ввода, обычно связанный с клавиатурой.

# %%
print('Enter some text:')
input_text = sys.stdin.readline().strip()
print(f'Received input: {input_text}')

# %% [markdown]
# ### sys.stdout
# Стандартный поток вывода, обычно связанный с экраном.

# %%
sys.stdout.write('Hello, stdout!\n')
# Out:
# Hello, stdout!
# 15

# %% [markdown]
# ### sys.stderr
# Стандартный поток ошибок.

# %%
sys.stderr.write('Error: something went wrong!\n')
# Out:
# Error: something went wrong!
# 29

# %% [markdown]
# ### sys.exit([arg])
# Завершает выполнение программы с указанным кодом выхода.

# %%
if len(sys.argv) < 2:
    print('Usage: python script.py <argument>')
    sys.exit(1)

# %% [markdown]
# ### sys.version
# Версия интерпретатора Python.

# %%
print('Python version:', sys.version)
# Out:
# Python version: 3.12.10 (main, Apr  9 2025, 04:03:51) [Clang 20.1.0 ]

# %% [markdown]
# ### sys.version_info
# Кортеж с информацией о версии интерпретатора Python.

# %%
print('Python version info:', sys.version_info)
# Out:
# Python version info: sys.version_info(major=3, minor=12, micro=10, releaselevel='final', serial=0)

# %% [markdown]
# ### sys.path
# Пути поиска модулей.

# %%
print('Python search paths:', sys.path)
# Out:
# Python search paths: ['/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python312.zip', '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12', '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/lib-dynload', '', '/home/evgeniy/code/py_experiments/.venv/lib/python3.12/site-packages']

# %% [markdown]
# ### sys.modules
# Словарь, в котором ключами являются имена загруженных модулей, а значениями - сами модули.

# %%
print('Loaded modules:', sys.modules)
# Out:
# Loaded modules: {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module '_frozen_importlib' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, '_io': <module '_io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'posix': <module 'posix' (built-in)>, '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>, 'time': <module 'time' (built-in)>, 'zipimport': <module 'zipimport' (frozen)>, '_codecs': <module '_codecs' (built-in)>, 'codecs': <module 'codecs' (frozen)>, 'encodings.aliases': <module 'encodings.aliases' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/encodings/aliases.py'>, 'encodings': <module 'encodings' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/encodings/__init__.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/encodings/utf_8.py'>, '_signal': <module '_signal' (built-in)>, '_abc': <module '_abc' (built-in)>, 'abc': <module 'abc' (frozen)>, 'io': <module 'io' (frozen)>, '__main__': <module '__main__'>, '_stat': <module '_stat' (built-in)>, 'stat': <module 'stat' (frozen)>, '_collections_abc': <module '_collections_abc' (frozen)>, 'genericpath': <module 'genericpath' (frozen)>, 'posixpath': <module 'posixpath' (frozen)>, 'os.path': <module 'posixpath' (frozen)>, 'os': <module 'os' (frozen)>, '_sitebuiltins': <module '_sitebuiltins' (frozen)>, 'encodings.utf_8_sig': <module 'encodings.utf_8_sig' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/encodings/utf_8_sig.py'>, '_virtualenv': <module '_virtualenv' from '/home/evgeniy/code/py_experiments/.venv/lib/python3.12/site-packages/_virtualenv.py'>, 'site': <module 'site' (frozen)>, 'importlib._bootstrap': <module '_frozen_importlib' (frozen)>, 'importlib._bootstrap_external': <module '_frozen_importlib_external' (frozen)>, 'warnings': <module 'warnings' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/warnings.py'>, 'importlib': <module 'importlib' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/importlib/__init__.py'>, 'importlib.machinery': <module 'importlib.machinery' (frozen)>, 'importlib._abc': <module 'importlib._abc' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/importlib/_abc.py'>, 'types': <module 'types' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/types.py'>, 'importlib.util': <module 'importlib.util' (frozen)>, 'runpy': <module 'runpy' (frozen)>, '_operator': <module '_operator' (built-in)>, 'operator': <module 'operator' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/operator.py'>, 'itertools': <module 'itertools' (built-in)>, 'keyword': <module 'keyword' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/keyword.py'>, 'reprlib': <module 'reprlib' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/reprlib.py'>, '_collections': <module '_collections' (built-in)>, 'collections': <module 'collections' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/collections/__init__.py'>, '_functools': <module '_functools' (built-in)>, 'functools': <module 'functools' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/functools.py'>, 'enum': <module 'enum' from '/home/evgeniy/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/enum.py'>, '_sre': <module '_sre' (built-in)>, 're._constants': <module 're._constants' from '/home/evgeniy/.local/share/uv/pyth ...

# %% [markdown]
# ### sys.executable
# Содержит путь к исполняемому файлу интерпретатора Python.

# %%
print('Path to Python executable:', sys.executable)
# Out:
# Path to Python executable: /home/evgeniy/code/py_experiments/.venv/bin/python

# %% [markdown]
# ### sys.platform
# Текущая платформа (например, 'linux', 'win32', 'darwin', ...)

# %%
print('Current platform:', sys.platform)
# Out:
# Current platform: linux

# %% [markdown]
# ### sys.getrecursionlimit()
# Максимальный предел рекурсии.

# %%
print(f'Current recursion limit: {sys.getrecursionlimit()}')
# Out:
# Current recursion limit: 3000

# %% [markdown]
# ### sys.setrecursionlimit(limit)
# Устанавливает максимальный предел рекурсии.

# %%
sys.setrecursionlimit(4000)
print(f'New recursion limit: {sys.getrecursionlimit()}')
# Out:
# New recursion limit: 4000

# %% [markdown]
# ### sys.getsizeof(obj)
# Размер объекта в байтах.

# %%
my_list = [1, 2, 3, 4, 5]
size = sys.getsizeof(my_list)
print(f'Size of the list: {size} bytes')
# Out:
# Size of the list: 104 bytes
